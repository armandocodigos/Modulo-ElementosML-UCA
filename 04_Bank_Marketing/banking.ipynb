# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from ucimlrepo import fetch_ucirepo
bank_marketing = fetch_ucirepo(id=222)

# %%
X = bank_marketing.data.features 
y = bank_marketing.data.targets

# %%
X.isna().sum()
# Out:
# age                0
# job              288
# marital            0
# education       1857
# default            0
# balance            0
# housing            0
# loan               0
# contact        13020
# day_of_week        0
# month              0
# duration           0
# campaign           0
# pdays              0
# previous           0
# poutcome       36959
# dtype: int64

# %%
X = X.dropna(subset = ["job", "education"])
X
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 5       35    management   married   tertiary      no      231     yes   no
# 6       28    management    single   tertiary      no      447     yes  yes
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day_of_week month  duration  campaign  pdays  previous  \
# 0            NaN            5   may       261         1     -1         0
# 1            NaN            5   may       151         1     -1         0
# 2            NaN            5   may        76         1     -1         0
# 5            NaN            5   may       139         1     -1         0
# 6            NaN            5   may       217         1     -1         0
# ...          ...          ...   ...       ...       ...    ...       ...
# 45206   cellular           17   nov       977         3     -1         0
# 45207   cellular           17   nov       456         2     -1         0
# 45208   cellular           17   nov      1127         5    184         3
# 45209  telephone           17   nov       508         4     -1         0
# 45210   cellular           17   nov       361         2    188        11
#
#       poutcome
# 0          NaN
# 1          NaN
# 2          NaN
# 5          NaN
# 6          NaN
# ...        ...
# 45206      NaN
# 45207      NaN
# 45208  success
# 45209      NaN
# 45210    other
#
# [43193 rows x 16 columns]

# %%
X = X.drop("contact", axis=1)
X = X.drop("poutcome", axis=1)
X
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 5       35    management   married   tertiary      no      231     yes   no
# 6       28    management    single   tertiary      no      447     yes  yes
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#        day_of_week month  duration  campaign  pdays  previous
# 0                5   may       261         1     -1         0
# 1                5   may       151         1     -1         0
# 2                5   may        76         1     -1         0
# 5                5   may       139         1     -1         0
# 6                5   may       217         1     -1         0
# ...            ...   ...       ...       ...    ...       ...
# 45206           17   nov       977         3     -1         0
# 45207           17   nov       456         2     -1         0
# 45208           17   nov      1127         5    184         3
# 45209           17   nov       508         4     -1         0
# 45210           17   nov       361         2    188        11
#
# [43193 rows x 14 columns]

# %%
X.isna().sum()
# Out:
# age            0
# job            0
# marital        0
# education      0
# default        0
# balance        0
# housing        0
# loan           0
# day_of_week    0
# month          0
# duration       0
# campaign       0
# pdays          0
# previous       0
# dtype: int64

# %%
datos = X.join(y)
datos
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 5       35    management   married   tertiary      no      231     yes   no
# 6       28    management    single   tertiary      no      447     yes  yes
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#        day_of_week month  duration  campaign  pdays  previous    y
# 0                5   may       261         1     -1         0   no
# 1                5   may       151         1     -1         0   no
# 2                5   may        76         1     -1         0   no
# 5                5   may       139         1     -1         0   no
# 6                5   may       217         1     -1         0   no
# ...            ...   ...       ...       ...    ...       ...  ...
# 45206           17   nov       977         3     -1         0  yes
# 45207           17   nov       456         2     -1         0  yes
# 45208           17   nov      1127         5    184         3  yes
# 45209           17   nov       508         4     -1         0   no
# 45210           17   nov       361         2    188        11   no
#
# [43193 rows x 15 columns]

# %%
y = datos[["y"]]
y
# Out:
#          y
# 0       no
# 1       no
# 2       no
# 5       no
# 6       no
# ...    ...
# 45206  yes
# 45207  yes
# 45208  yes
# 45209   no
# 45210   no
#
# [43193 rows x 1 columns]

# %%
X = datos.drop("y", axis=1)
X
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 5       35    management   married   tertiary      no      231     yes   no
# 6       28    management    single   tertiary      no      447     yes  yes
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#        day_of_week month  duration  campaign  pdays  previous
# 0                5   may       261         1     -1         0
# 1                5   may       151         1     -1         0
# 2                5   may        76         1     -1         0
# 5                5   may       139         1     -1         0
# 6                5   may       217         1     -1         0
# ...            ...   ...       ...       ...    ...       ...
# 45206           17   nov       977         3     -1         0
# 45207           17   nov       456         2     -1         0
# 45208           17   nov      1127         5    184         3
# 45209           17   nov       508         4     -1         0
# 45210           17   nov       361         2    188        11
#
# [43193 rows x 14 columns]

# %%
#Dummies: job, marital
#Encoder: default, housing, loan
#Encoder (map): education, month

# %%
X["month"].value_counts()
# Out:
# month
# may    13192
# jul     6601
# aug     6037
# jun     4980
# nov     3842
# apr     2820
# feb     2533
# jan     1318
# oct      690
# sep      532
# mar      448
# dec      200
# Name: count, dtype: int64

# %%
X = pd.get_dummies(X, columns=["job", "marital"])
X.head()
# Out:
#    age  education default  balance housing loan  day_of_week month  duration  \
# 0   58   tertiary      no     2143     yes   no            5   may       261
# 1   44  secondary      no       29     yes   no            5   may       151
# 2   33  secondary      no        2     yes  yes            5   may        76
# 5   35   tertiary      no      231     yes   no            5   may       139
# 6   28   tertiary      no      447     yes  yes            5   may       217
#
#    campaign  ...  job_management  job_retired  job_self-employed  \
# 0         1  ...            True        False              False
# 1         1  ...           False        False              False
# 2         1  ...           False        False              False
# 5         1  ...            True        False              False
# 6         1  ...            True        False              False
#
#    job_services  job_student  job_technician  job_unemployed  \
# 0         False        False           False           False
# 1         False        False            True           False
# 2         False        False           False           False
# 5         False        False           False           False
# 6         False        False           False           False
#
#    marital_divorced  marital_married  marital_single
# 0             False             True           False
# 1             False            False            True
# 2             False             True           False
# 5             False             True           False
# 6             False            False            True
#
# [5 rows x 26 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()

# %%
X.loc[:, "default"] = encoder.fit_transform(X[["default"]])
X.loc[:, "housing"] = encoder.fit_transform(X[["housing"]])
X.loc[:, "loan"] = encoder.fit_transform(X[["loan"]])
X.head()
# Out:
#    age  education default  balance housing loan  day_of_week month  duration  \
# 0   58   tertiary     0.0     2143     1.0  0.0            5   may       261
# 1   44  secondary     0.0       29     1.0  0.0            5   may       151
# 2   33  secondary     0.0        2     1.0  1.0            5   may        76
# 5   35   tertiary     0.0      231     1.0  0.0            5   may       139
# 6   28   tertiary     0.0      447     1.0  1.0            5   may       217
#
#    campaign  ...  job_management  job_retired  job_self-employed  \
# 0         1  ...            True        False              False
# 1         1  ...           False        False              False
# 2         1  ...           False        False              False
# 5         1  ...            True        False              False
# 6         1  ...            True        False              False
#
#    job_services  job_student  job_technician  job_unemployed  \
# 0         False        False           False           False
# 1         False        False            True           False
# 2         False        False           False           False
# 5         False        False           False           False
# 6         False        False           False           False
#
#    marital_divorced  marital_married  marital_single
# 0             False             True           False
# 1             False            False            True
# 2             False             True           False
# 5             False             True           False
# 6             False            False            True
#
# [5 rows x 26 columns]

# %%
map_dict = {'primary': 1, 'secondary': 2, 'tertiary': 3}
X['education'] = X['education'].map(map_dict)
X.head()
# Out:
#    age  education default  balance housing loan  day_of_week month  duration  \
# 0   58          3     0.0     2143     1.0  0.0            5   may       261
# 1   44          2     0.0       29     1.0  0.0            5   may       151
# 2   33          2     0.0        2     1.0  1.0            5   may        76
# 5   35          3     0.0      231     1.0  0.0            5   may       139
# 6   28          3     0.0      447     1.0  1.0            5   may       217
#
#    campaign  ...  job_management  job_retired  job_self-employed  \
# 0         1  ...            True        False              False
# 1         1  ...           False        False              False
# 2         1  ...           False        False              False
# 5         1  ...            True        False              False
# 6         1  ...            True        False              False
#
#    job_services  job_student  job_technician  job_unemployed  \
# 0         False        False           False           False
# 1         False        False            True           False
# 2         False        False           False           False
# 5         False        False           False           False
# 6         False        False           False           False
#
#    marital_divorced  marital_married  marital_single
# 0             False             True           False
# 1             False            False            True
# 2             False             True           False
# 5             False             True           False
# 6             False            False            True
#
# [5 rows x 26 columns]

# %%
map_dict = {'jan': 1, 'feb': 2, 'mar': 3, 'apr': 4, 'may': 5, 'jun': 6, 'jul': 7, 'aug': 8, 'sep': 9, 'oct': 10, 'nov': 11, 'dec': 12}
X['month'] = X['month'].map(map_dict)
X.head()
# Out:
#    age  education default  balance housing loan  day_of_week  month  duration  \
# 0   58          3     0.0     2143     1.0  0.0            5      5       261
# 1   44          2     0.0       29     1.0  0.0            5      5       151
# 2   33          2     0.0        2     1.0  1.0            5      5        76
# 5   35          3     0.0      231     1.0  0.0            5      5       139
# 6   28          3     0.0      447     1.0  1.0            5      5       217
#
#    campaign  ...  job_management  job_retired  job_self-employed  \
# 0         1  ...            True        False              False
# 1         1  ...           False        False              False
# 2         1  ...           False        False              False
# 5         1  ...            True        False              False
# 6         1  ...            True        False              False
#
#    job_services  job_student  job_technician  job_unemployed  \
# 0         False        False           False           False
# 1         False        False            True           False
# 2         False        False           False           False
# 5         False        False           False           False
# 6         False        False           False           False
#
#    marital_divorced  marital_married  marital_single
# 0             False             True           False
# 1             False            False            True
# 2             False             True           False
# 5             False             True           False
# 6             False            False            True
#
# [5 rows x 26 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(X, test_size=0.2, random_state=42)
#train: 80%
#test: 20%
X_train.shape, X_test.shape
# Out:
# ((34554, 26), (8639, 26))

# %%
y_train, y_test = train_test_split(y, test_size=0.2, random_state=42)
y_train = np.reshape(y_train, -1)
y_test = np.reshape(y_test, -1)
y_train.shape, y_test.shape
# Out:
# ((34554,), (8639,))

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[7098,  560],
#        [ 521,  460]])

# %%
disp = ConfusionMatrixDisplay(confusion_matrix = cm)
disp.plot()
plt.show()
